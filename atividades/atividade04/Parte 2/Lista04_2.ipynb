# %% [markdown]
# # Lista 04 - Parte 2
#
# ## Nome: Jorge Lucas Colares Martins
# ## Matricula: 402119

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import random
import math
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import precision_score

# %% [markdown]
# ### Questão 01

# %%
df = pd.read_csv('winequality-white.csv',delimiter=';')
df['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# ### Questão 02

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('quality',axis=1), df['quality'], test_size=0.3, random_state= 42)

# %% [markdown]
# ### Questão 03

# %%
knn1 = KNeighborsClassifier(n_neighbors=1)
knn2 = KNeighborsClassifier(n_neighbors=2)
knn3 = KNeighborsClassifier(n_neighbors=3)
knn4 = KNeighborsClassifier(n_neighbors=4)
knn5 = KNeighborsClassifier(n_neighbors=5)

knn1.fit(X_train, y_train)
knn2.fit(X_train, y_train)
knn3.fit(X_train, y_train)
knn4.fit(X_train, y_train)
knn5.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Questão 04

# %%
resultado1 = knn1.predict(X_test)
resultado2 = knn2.predict(X_test)
resultado3 = knn3.predict(X_test)
resultado4 = knn4.predict(X_test)
resultado5 = knn5.predict(X_test)


print(knn1.score(X_test,y_test))
print(knn2.score(X_test,y_test))
print(knn3.score(X_test,y_test))
print(knn4.score(X_test,y_test))
print(knn5.score(X_test,y_test))
# Out:
# 0.5591836734693878
# 0.5047619047619047
# 0.47891156462585033
# 0.47278911564625853
# 0.47551020408163264
