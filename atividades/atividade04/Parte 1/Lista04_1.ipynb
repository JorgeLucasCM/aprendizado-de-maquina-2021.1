# %% [markdown]
# # Lista 04 - Parte 1
#
# ## Nome: Jorge Lucas Colares Martins
# ## Matricula: 402119

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import random
import math

# %% [markdown]
# ### Importando o dataset

# %%
df = pd.read_csv('/content/Iris.csv')

# %% [markdown]
# ### Dividindo conjuntos de treino e teste

# %%
trainSet = df.sample(frac=0.7, random_state= 42)
testSet = df.drop(trainSet.index)

X_train = trainSet.drop('Species', axis=1)
y_train = trainSet['Species']

X_test = testSet.drop('Species', axis=1)
y_test = testSet['Species']

# %% [markdown]
# ### Adicionado funções dos vizinhos

# %%
def euclidean_distances(X, X_row):
    X_ = (X - X_row) ** 2
    return np.sum(X_, axis=1) ** 0.5

# %%
def get_neighbors(X_train, test_row, k):
    distances = euclidean_distances(X_train, test_row)
    idx_sort = np.argsort(distances)
    return idx_sort[:k]

# %%
def predict_classification(X, y, test_row, k):
    idx_sort = get_neighbors(X, test_row, k)
    output_values = y[idx_sort]
    counts = np.unique(output_values, return_counts=True)
    idx_max = np.argmax(counts[1])
    prediction = counts[0][idx_max]
    return prediction

# %% [markdown]
# ### Fazendo as classificações

# %% [markdown]
# #### Classificação para K=3

# %%
k = 3
prediction_3 = []
for x in range(len(y_test)):
  prediction_3.append(predict_classification(X_train.values, y_train.values, X_test.values[x] , k))

# %% [markdown]
# ##### Acurácia

# %%
print("Acurácia de {}%".format(np.sum(prediction_3 == y_test) * 100 / y_test.shape[0]))
# Out:
# Acurácia de 100.0%

# %% [markdown]
# #### Classificação para K = 5

# %%
k = 5
prediction_5 = []
for x in range(len(y_test)):
  prediction_5.append(predict_classification(X_train.values, y_train.values, X_test.values[x] , k))

# %% [markdown]
# ##### Acurácia

# %%
print("Acurácia de {}%".format(np.sum(prediction_5 == y_test) * 100 / y_test.shape[0]))
# Out:
# Acurácia de 97.77777777777777%
